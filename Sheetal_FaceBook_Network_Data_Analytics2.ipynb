# %% [markdown]
# <a href="https://colab.research.google.com/github/sheetal-kumar/repos/blob/main/Sheetal_FaceBook_Network_Data_Analytics2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import networkx as nx

# %%
G_fb = nx.read_edgelist("facebook_combined.txt", create_using = nx.Graph(), nodetype=int)

# %%
print(nx.info(G_fb))
# Out:
# Graph with 4039 nodes and 88234 edges

# %%
print(nx.info(G_fb))
# Out:
# Graph with 4039 nodes and 88234 edges

# %%
pos = nx.spring_layout(G_fb)
betCent = nx.betweenness_centrality(G_fb, normalized=True, endpoints=True)
node_color = [20000.0 * G_fb.degree(v) for v in G_fb]
node_size =  [v * 10000 for v in betCent.values()]
plt.figure(figsize=(20,20))
nx.draw_networkx(G_fb, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
# Out:
# (-0.6144942724704743,
#  1.153413482904434,
#  -0.8459701582789421,
#  0.7353767797350883)

# %%
sorted(betCent, key=betCent.get, reverse=True)[:5]
# Out:
# [107, 1684, 3437, 1912, 1085]

# %%
betCent2 = nx.degree_centrality(G_fb)
sorted(betCent2, key=betCent2.get, reverse=True)[:5]
# Out:
# [107, 1684, 1912, 3437, 0]

# %%
betCent3 = nx.eigenvector_centrality(G_fb)
sorted(betCent3, key=betCent3.get, reverse=True)[:5]
# Out:
# [1912, 2266, 2206, 2233, 2464]

# %%
nx.average_clustering(G_fb)
# Out:
# 0.6055467186200876
